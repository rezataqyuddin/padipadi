# %%
## for data
import numpy as np
import pandas as pd
## for plotting
import matplotlib.pyplot as plt
import seaborn as sns
## for geospatial
import folium
import geopy
## for machine learning
from sklearn import preprocessing, cluster
import scipy
## for deep learning
import minisom

# %%
dnapadi = pd.read_csv('../dataset/rice_dataset_cl_discretized.csv')

# %%
dnapadi.head()
# Out:
#    occurrence     start       end   mismatch hr12_prod_size ref_prod_size  \
# 0      ≥ 12.5  ≥ 145490  ≥ 145787  0.5 - 1.5        < 160.5       < 163.5
# 1  7.5 - 12.5  ≥ 145490  ≥ 145787  0.5 - 1.5        < 160.5       < 163.5
# 2  7.5 - 12.5  ≥ 145490  ≥ 145787  0.5 - 1.5  160.5 - 257.5       < 163.5
# 3      ≥ 12.5  ≥ 145490  ≥ 145787  0.5 - 1.5        ≥ 257.5       ≥ 255.5
# 4      ≥ 12.5  ≥ 145490  ≥ 145787  0.5 - 1.5        ≥ 257.5       ≥ 255.5
#
#       npb cult_93_11    tetep  tadukan ﻿chr_number mark_name motifs Cluster  \
# 0  Absent     Absent  Present  Present   Chr1_HR12    RM5646    AAG      C3
# 1  Absent     Absent  Present  Present   Chr1_HR12    RM6875    TGG      C3
# 2  Absent     Absent  Present  Present   Chr1_HR12    RM6666    TAA      C3
# 3  Absent     Absent   Absent   Absent   Chr1_HR12    RM8130     GT      C3
# 4  Absent     Absent   Absent   Absent   Chr1_HR12    RM8130     AT      C3
#
#    Silhouette
# 0    0.580372
# 1    0.605171
# 2    0.624666
# 3    0.592902
# 4    0.594532

# %%
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.model_selection import train_test_split

from frlearn.base import probabilities_from_scores, select_class
from frlearn.classifiers import FRNN
from frlearn.feature_preprocessors import RangeNormaliser

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(dnapadi, test_size=0.2)

train.columns
clf = FRNN(preprocessors=(RangeNormaliser(), ))
model = clf(train.iloc[:,0:12],train["Cluster"])
scores = model(test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/whoasara/Dev/padi/roughsets/clustering.ipynb Cell 5' in <cell line: 7>()
#       <a href='vscode-notebook-cell:/Users/whoasara/Dev/padi/roughsets/clustering.ipynb#ch0000004?line=4'>5</a> train.columns
#       <a href='vscode-notebook-cell:/Users/whoasara/Dev/padi/roughsets/clustering.ipynb#ch0000004?line=5'>6</a> clf = FRNN(preprocessors=(RangeNormaliser(), ))
# ----> <a href='vscode-notebook-cell:/Users/whoasara/Dev/padi/roughsets/clustering.ipynb#ch0000004?line=6'>7</a> model = clf(train.iloc[:,0:12],train["Cluster"])
#       <a href='vscode-notebook-cell:/Users/whoasara/Dev/padi/roughsets/clustering.ipynb#ch0000004?line=7'>8</a> scores = model(test)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/frlearn/base.py:83, in ClassSupervised.__call__(self, X, y)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/frlearn/base.py?line=81'>82</a> def __call__(self, X, y) -> ClassSupervised.Model:
# ---> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/frlearn/base.py?line=82'>83</a>     return super().__call__(X, y=y)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/frlearn/base.py:29, in SoftMachine.__call__(self, X, **kwargs)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/frlearn/base.py?line=26'>27</a> for preprocessor in self.preprocessors:
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/frlearn/base.py?line=27'>28</a>     extra_kwargs = {k: v for k, v in kwargs.items() if k in signature(preprocessor.__call__).parameters}
# ---> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/frlearn/base.py?line=28'>29</a>     preprocessing_model = preprocessor(X, **extra_kwargs)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/frlearn/base.py?line=29'>30</a>     X = preprocessing_model(X)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/frlearn/base.py?line=30'>31</a>     preprocessing_models.append(preprocessing_model)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/frlearn/base.py:70, in Unsupervised.__call__(self, X)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/frlearn/base.py?line=68'>69</a> def __call__(self, X) -> Unsupervised.Model:
# ---> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/frlearn/base.py?line=69'>70</a>     return super().__call__(X, )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/frlearn/base.py:32, in SoftMachine.__call__(self, X, **kwargs)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/frlearn/base.py?line=29'>30</a>     X = preprocessing_model(X)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/frlearn/base.py?line=30'>31</a>     preprocessing_models.append(preprocessing_model)
# ---> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/frlearn/base.py?line=31'>32</a> model = self._construct(X, **kwargs)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/frlearn/base.py?line=32'>33</a> model.preprocessing_models = preprocessing_models
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/frlearn/base.py?line=33'>34</a> return model
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/frlearn/statistics/feature_preprocessors.py:38, in LinearNormaliser._construct(self, X)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/frlearn/statistics/feature_preprocessors.py?line=35'>36</a> model = super()._construct(X)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/frlearn/statistics/feature_preprocessors.py?line=36'>37</a> if self.dispersion is not None:
# ---> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/frlearn/statistics/feature_preprocessors.py?line=37'>38</a>     divisor = self.dispersion(X)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/frlearn/statistics/feature_preprocessors.py?line=38'>39</a>     divisor = np.where(divisor == 0 | np.isnan(divisor), 1, divisor)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/frlearn/statistics/feature_preprocessors.py?line=39'>40</a> else:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/frlearn/statistics/dispersion_measures.py:80, in total_range(X)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/frlearn/statistics/dispersion_measures.py?line=61'>62</a> def total_range(X):
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/frlearn/statistics/dispersion_measures.py?line=62'>63</a>     """
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/frlearn/statistics/dispersion_measures.py?line=63'>64</a>     Distance between the smallest and largest value.
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/frlearn/statistics/dispersion_measures.py?line=64'>65</a>
#    (...)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/frlearn/statistics/dispersion_measures.py?line=77'>78</a>     This function is not called `range` so as not to overwrite the built-in function `range`.
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/frlearn/statistics/dispersion_measures.py?line=78'>79</a>     """
# ---> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/frlearn/statistics/dispersion_measures.py?line=79'>80</a>     return np.nanmax(X, axis=0) - np.nanmin(X, axis=0)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
